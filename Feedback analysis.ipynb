# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import BernoulliNB

# %%
raw_report = open('amazon_cells_labelled.txt')
raw_report = pd.read_table(raw_report,delimiter = '\t', header = None)
raw_report.columns = ['message', 'sentiment']

# %%
positive_list = raw_report.copy()
positive_keywords = ['good','great','best']

negative_list = raw_report.copy()
negative_keywords = ['junk','waste','disappoint']

# %%
for key in positive_keywords : 
    positive_list[str(key)] = positive_list.message.str.contains(
    ' '+ str(key) +' ',
        case = False
    )
positive_list

positive_heat = positive_list.copy()

# %% [markdown]
# ** NOT RERUN BELOW CELL !!!!!!!!**

# %%
positive_heat['sentiment'] = (positive_heat['sentiment'] == 1)
sns.heatmap(positive_heat.corr())

# %%
data_pos = positive_heat[postive_keywords]
target_pos = positive_heat['sentiment']

# %%
bnb = BernoulliNB()

bnb.fit(data_pos,target_pos)

y_pred = bnb.predict(data_pos)

print('Number of mislabeled points out of total {} points : {}'.format(
      data_pos.shape[0],
      (target_pos != y_pred).sum() 
))
# Out:
# Number of mislabeled points out of total 1000 points : 429

# %%
for value in negative_keywords : 
    negative_list[str(value)] = negative_list.message.str.contains(
    ' '+ str(value) +' ',
        case = False
    )

# %%
negative_df = negative_list.copy()
negative_df
# Out:
#                                                message  sentiment   junk  \
# 0    So there is no way for me to plug it in here i...          0  False
# 1                          Good case, Excellent value.          1  False
# 2                               Great for the jawbone.          1  False
# 3    Tied to charger for conversations lasting more...          0  False
# 4                                    The mic is great.          1  False
# 5    I have to jiggle the plug to get it to line up...          0  False
# 6    If you have several dozen or several hundred c...          0  False
# 7          If you are Razr owner...you must have this!          1  False
# 8                  Needless to say, I wasted my money.          0  False
# 9                     What a waste of money and time!.          0  False
# 10                     And the sound quality is great.          1  False
# 11   He was very impressed when going from the orig...          1  False
# ...

# %%
## Do Not Re Run 
negative_df['sentiment'] = (negative_df['sentiment'] == 0)
negative_df
# Out:
#                                                message  sentiment   junk  \
# 0    So there is no way for me to plug it in here i...       True  False
# 1                          Good case, Excellent value.      False  False
# 2                               Great for the jawbone.      False  False
# 3    Tied to charger for conversations lasting more...       True  False
# 4                                    The mic is great.      False  False
# 5    I have to jiggle the plug to get it to line up...       True  False
# 6    If you have several dozen or several hundred c...       True  False
# 7          If you are Razr owner...you must have this!      False  False
# 8                  Needless to say, I wasted my money.       True  False
# 9                     What a waste of money and time!.       True  False
# 10                     And the sound quality is great.      False  False
# 11   He was very impressed when going from the orig...      False  False
# ...

# %%
sns.heatmap(negative_df.corr())

# %%
data_neg = negative_df[negative_keywords]
target_neg = negative_df['sentiment']

# %%
bnb = BernoulliNB()

bnb.fit(data_neg,target_pos)

x_pred = bnb.predict(data_neg)

print('Number of mislabeled points out of total {} points : {}'.format(
      data_neg.shape[0],
      (target_pos != x_pred).sum() 
))
# Out:
# Number of mislabeled points out of total 1000 points : 487

# %%
new_report = open('yelp_labelled.txt')
new_report = pd.read_table(new_report,delimiter = '\t', header = None)
new_report.columns = ['message', 'sentiment']

# %%
new_positive_list = new_report.copy()
positive_keywords = ['good','great','best']

new_negative_list = new_report.copy()
negative_keywords = ['junk','waste','disappoint']

# %%
for key in positive_keywords : 
    new_positive_list[str(key)] = new_positive_list.message.str.contains(
    ' '+ str(key) +' ',
        case = False
    )
new_positive_list

yelp_positive_heat = new_positive_list.copy()

# %%
## Do not rerun
yelp_positive_heat['sentiment'] = (yelp_positive_heat['sentiment'] == 1)
sns.heatmap(yelp_positive_heat.corr())

# %%
data_pos = yelp_positive_heat[positive_keywords]
target_pos = yelp_positive_heat['sentiment']

# %%
bnb = BernoulliNB()

bnb.fit(data_pos,target_pos)

y_pred = bnb.predict(data_pos)

print('Number of mislabeled points out of total {} points : {}'.format(
      data_pos.shape[0],
      (target_pos != y_pred).sum() 
))
# Out:
# Number of mislabeled points out of total 1000 points : 423

# %% [markdown]
# I used key words to determine if the sentiment was positive or negative. I choose three words for positive and negative based on quickly scanning the raw files. In order to create a better keyword list should be created.
